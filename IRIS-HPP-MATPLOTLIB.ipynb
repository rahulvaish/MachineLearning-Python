# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#Loading the complete File

# %%
irisCompleteData= pd.read_csv("C:/Users/Lenovo/Desktop/IPY/iris.csv")

# %%
g = sns.pairplot(irisCompleteData)

# %%
houseData= pd.read_csv("D:/DataScienceCollection/DataSets/HousePriceData/house_data.csv")

# %%
g=sns.pairplot(houseData)

# %%
g.savefig("C:/Users/Lenovo/Desktop/IPY/house.png")
