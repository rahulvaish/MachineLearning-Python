# %%
import pandas as pd

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }

# %%
#boys = pd.read_csv('C:/Users/rvaish/Documents/Python Scripts/Data/schools_with_btoilet.csv')

# %%
girls = pd.read_csv('C:/Users/rvaish/Documents/Python Scripts/Data/schools_with_gtoilet.csv')

# %%
girls
# Out:
#                       State_UT     year  Primary_Only  Primary_with_U_Primary  \
# 0                    All India  2013-14         88.68                   95.98
# 1                    All India  2014-15         91.21                   96.92
# 2                    All India  2015-16         96.95                   99.03
# 3    Andaman & Nicobar Islands  2013-14         89.74                   97.37
# 4    Andaman & Nicobar Islands  2014-15        100.00                  100.00
# 5    Andaman & Nicobar Islands  2015-16        100.00                  100.00
# 6               Andhra Pradesh  2013-14         76.16                   89.46
# 7               Andhra Pradesh  2014-15         97.79                   98.81
# 8               Andhra Pradesh  2015-16         99.60                   99.89
# 9            Arunachal Pradesh  2013-14         67.77                   88.88
# 10           Arunachal Pradesh  2014-15         94.92                   99.74
# ...

# %%
print(list(girls.columns))
# Out:
# ['State_UT', 'year', 'Primary_Only', 'Primary_with_U_Primary', 'Primary_with_U_Primary_Sec_HrSec', 'U_Primary_Only', 'U_Primary_With_Sec_HrSec', 'Primary_with_U_Primary_Sec', 'U_Primary_With_Sec', 'Sec_Only', 'Sec_with_HrSec.', 'HrSec_Only', 'All Schools']

# %%
girls_Pivot_State_UT_Year = pd.pivot_table(girls, index = ['State_UT','year'])

# %%
girls_Pivot_State_UT_Year.head(5)
# Out:
#                                    All Schools  HrSec_Only  Primary_Only  \
# State_UT                  year
# All India                 2013-14        91.23       76.14         88.68
#                           2014-15        93.08       90.94         91.21
#                           2015-16        97.52       96.22         96.95
# Andaman & Nicobar Islands 2013-14        93.44        0.00         89.74
#                           2014-15       100.00        0.00        100.00
#
#                                    Primary_with_U_Primary  \
# State_UT                  year
# All India                 2013-14                   95.98
#                           2014-15                   96.92
#                           2015-16                   99.03
# Andaman & Nicobar Islands 2013-14                   97.37
#                           2014-15                  100.00
#
#                                    Primary_with_U_Primary_Sec  \
# State_UT                  year
# ...

# %%
girls_Pivot_State_UT_Year_Count = pd.pivot_table(girls, index = ['State_UT'],  aggfunc='count')

# %%
girls_Pivot_State_UT_Year_Count.head(5)
# Out:
#                            All Schools  HrSec_Only  Primary_Only  \
# State_UT
# All India                            3           3             3
# Andaman & Nicobar Islands            3           3             3
# Andhra Pradesh                       3           3             3
# Arunachal Pradesh                    3           3             3
# Assam                                3           3             3
#
#                            Primary_with_U_Primary  Primary_with_U_Primary_Sec  \
# State_UT
# All India                                       3                           3
# Andaman & Nicobar Islands                       3                           3
# Andhra Pradesh                                  3                           3
# Arunachal Pradesh                               3                           3
# Assam                                           3                           3
#
#                            Primary_with_U_Primary_Sec_HrSec  Sec_Only  \
# State_UT
# ...

# %%
girls_Pivot_State_UT_Year_Median = pd.pivot_table(girls, index = ['State_UT'],  aggfunc='median')

# %%
girls_Pivot_State_UT_Year_Median.head(5)
# Out:
#                            All Schools  HrSec_Only  Primary_Only  \
# State_UT
# All India                        93.08       90.94         91.21
# Andaman & Nicobar Islands       100.00        0.00        100.00
# Andhra Pradesh                   98.07       94.73         97.79
# Arunachal Pradesh                96.56        0.00         94.41
# Assam                            75.28       72.31         77.97
#
#                            Primary_with_U_Primary  Primary_with_U_Primary_Sec  \
# State_UT
# All India                                   96.92                       98.19
# Andaman & Nicobar Islands                  100.00                      100.00
# Andhra Pradesh                              98.81                       99.57
# Arunachal Pradesh                           99.59                       99.55
# Assam                                       82.94                       89.88
#
#                            Primary_with_U_Primary_Sec_HrSec  Sec_Only  \
# State_UT
# ...

# %%
girls_Pivot_State_UT_Year_Mean = pd.pivot_table(girls, index = ['State_UT'],  aggfunc='mean')

# %%
girls_Pivot_State_UT_Year_Mean.head(5)
# Out:
#                            All Schools  HrSec_Only  Primary_Only  \
# State_UT
# All India                    93.943333   87.766667     92.280000
# Andaman & Nicobar Islands    97.813333    0.000000     96.580000
# Andhra Pradesh               93.033333   90.066667     91.183333
# Arunachal Pradesh            90.116667   33.333333     85.700000
# Assam                        78.026667   51.753333     80.460000
#
#                            Primary_with_U_Primary  Primary_with_U_Primary_Sec  \
# State_UT
# All India                               97.310000                   98.276667
# Andaman & Nicobar Islands               99.123333                  100.000000
# Andhra Pradesh                          96.053333                   96.723333
# Arunachal Pradesh                       96.070000                   99.023333
# Assam                                   83.640000                   89.520000
#
#                            Primary_with_U_Primary_Sec_HrSec   Sec_Only  \
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
sns.set()  # use Seaborn styles
girls_Pivot_State_UT_Year = pd.pivot_table(girls, index = ['State_UT','year'])
girls_Pivot_State_UT_Year['Primary_Only'].head(3).plot(kind="bar",color=['r','b','g'])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
sns.set()  # use Seaborn styles
girls_Pivot_State_UT_Year = pd.pivot_table(girls, index = ['State_UT','year'])
girls_Pivot_State_UT_Year['Bihar','Sec_Only'].head(3).plot(kind="bar",color=['r','b','g'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Bihar', 'Sec_Only')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-296-c13dc40b911e> in <module>()
# ...
